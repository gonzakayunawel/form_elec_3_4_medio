# %% [markdown]
# ## Creación de la base de datos

# %%
import sqlite3

def create_users_register_table():
    conn = sqlite3.connect("form_app.db")
    cursor = conn.cursor()
    cursor.execute(
        """
        CREATE TABLE IF NOT EXISTS users_register (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            name TEXT,
            email TEXT,
            run TEXT,
            curso TEXT,
            electivo_1 TEXT,
            electivo_2 TEXT,
            electivo_3 TEXT,
            electivo_fg TEXT,
            created_at DATETIME DEFAULT CURRENT_TIMESTAMP
        )
        """
    )
    conn.commit()
    conn.close()

def create_email_table():
    conn = sqlite3.connect("form_app.db")
    cursor = conn.cursor()
    cursor.execute(
        """
        CREATE TABLE IF NOT EXISTS emails (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            email TEXT,
            run TEXT,
            created_at DATETIME DEFAULT CURRENT_TIMESTAMP
        )
        """
    )
    conn.commit()
    conn.close()
    
def create_electives_table():
    conn = sqlite3.connect("form_app.db")
    cursor = conn.cursor()
    cursor.execute(
        """
        CREATE TABLE IF NOT EXISTS electives_control (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            electivos_disponibles TEXT
        )
        """
    )
    conn.commit()
    conn.close()

def create_electives_list_2024_3_medio_table():
    conn = sqlite3.connect("form_app.db")
    cursor = conn.cursor()
    cursor.execute(
        """
        CREATE TABLE IF NOT EXISTS listado_electivos_2024_3_medio (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            run TEXT,
            curso TEXT,
            electivo_1 TEXT,
            electivo_2 TEXT,
            electivo_3 TEXT
        )
        """
    )
    conn.commit()
    conn.close()

# %%
create_electives_list_2024_3_medio_table()

# %%
create_email_table()

# %% [markdown]
# ## Leer el contenido de una tabla

# %%
import pandas as pd
import sqlite3  # Asegúrate de importar sqlite3

def read_table(table_name, db='form_app.db'):
    conn = sqlite3.connect(db)
    cursor = conn.cursor()

    try:
        cursor.execute(f"PRAGMA table_info({table_name});")
        att_table = [info[1] for info in cursor.fetchall()]

        cursor.execute(f"SELECT * FROM {table_name};")
        table_content = cursor.fetchall()

        df_table = pd.DataFrame(table_content, columns=att_table)
    except Exception as e:
        print(f"Error: {e}")
        df_table = pd.DataFrame()  # Devolver un DataFrame vacío en caso de error
    finally:
        conn.close()

    return df_table

# %%
table_name = "listado_electivos_2024_3_medio"
db = "form_app.db"

read_table(table_name, db)
# Out:
#     id        run       curso                     electivo_1  \
# 0    1  224332564  3º Medio B                         Física
# 1    2  22464776K  3º Medio A  Participación y Argumentación
# 2    3  224793626  3º Medio B          Diseño y arquitectura
# 3    4  224793839  3º Medio B  Participación y Argumentación
# 4    5  225014434  3º Medio A  Participación y Argumentación
# ..  ..        ...         ...                            ...
# 69  70  226483306  3º Medio B  Participación y Argumentación
# 70  71  226600493  3º Medio A  Participación y Argumentación
# 71  72  226821848  3º Medio B          Diseño y arquitectura
# 72  73  227016558  3º Medio B  Participación y Argumentación
# 73  74  227150645  3º Medio B                         Física
#
#                                    electivo_2              electivo_3
# 0   Ciencias del Ejercicio Físico y Deportivo  Interpretación Musical
# 1                         Economía y Sociedad  Interpretación Musical
# 2                Biología celular y molecular  Interpretación Musical
# 3                         Economía y Sociedad  Interpretación Musical
# 4                         Economía y Sociedad  Interpretación Musical
# ..                                        ...                     ...
# 69                       Ciencias de la salud  Seminario de filosofía
# 70                       Ciencias de la salud  Seminario de filosofía
# 71               Biología celular y molecular  Seminario de filosofía
# 72                       Ciencias de la salud  Seminario de filosofía
# 73  Ciencias del Ejercicio Físico y Deportivo  Seminario de filosofía
#
# [74 rows x 6 columns]

# %% [markdown]
# ## Eliminar los datos de la tabla

# %%
import sqlite3

table_name = "users_register"
db = "form_app.db"

def delete_all_data_from_table(table_name, db):
    conn = sqlite3.connect(db)
    cursor = conn.cursor()

    try:
        cursor.execute(f"DELETE FROM {table_name};")  # Elimina todos los datos
        conn.commit()  # Asegúrate de guardar los cambios
        print(f"Todos los datos de la tabla '{table_name}' han sido eliminados.")
    except Exception as e:
        print(f"Error al eliminar datos: {e}")
    finally:
        conn.close()  # Asegúrate de cerrar la conexión

def drop_table(table_name, db):
    conn = sqlite3.connect(db)
    cursor = conn.cursor()

    try:
        cursor.execute(f"DROP TABLE {table_name};")  # Elimina la tabla
        conn.commit()  # Asegúrate de guardar los cambios
        print(f"La tabla '{table_name}' ha sido eliminada.")
    except Exception as e:
        print(f"Error al eliminar la tabla: {e}")
    finally:
        conn.close()  # Asegúrate de cerrar la conexión

# %%
# Llamar a la función
delete_all_data_from_table('emails', 'form_app.db')
# Out:
# Todos los datos de la tabla 'emails' han sido eliminados.

# %%
table_name = "emails"

read_table(table_name, db)
# Out:
# Empty DataFrame
# Columns: [id, email, run, created_at]
# Index: []

# %%
table_name = "emails"

# read_table(table_name, db)
# delete_all_data_from_table(table_name, db)
# drop_table(table_name, db)
# Out:
# La tabla 'emails' ha sido eliminada.

# %% [markdown]
# ## Insertar emails a la tabla email

# %%
def insert_email(run, email):
    conn = sqlite3.connect('form_app.db')
    cursor = conn.cursor()
    cursor.execute(
        """
        INSERT INTO emails (run, email)
        VALUES (?, ?)
        """,
        (run, email),
    )
    conn.commit()
    conn.close()

# %%
df_users_II_G = pd.read_excel("correos.xlsx", sheet_name=0)
df_users_II_G.columns

# insert_email("micorreo@gmail.com")
# Out:
# Index(['Nº de lista', 'RUN', 'Género', 'Apellido paterno', 'Apellido materno',
#        'Nombres', 'Email', 'Fono estudiante', 'Dirección del estudiante',
#        'Nombre contacto emergencia', 'Fono emergencia'],
#       dtype='object')

# %%
df_users_II_B = pd.read_excel("correos.xlsx", sheet_name=1)
df_users_II_B
# Out:
#     Nº de lista        RUN Género Apellido paterno Apellido materno  \
# 0             1  227986972      M          Acevedo           Guzmán
# 1             2  228985147      F          Acevedo           Osorio
# 2             3  226415637      F          Aguilar         Riquelme
# 3             4  223846807      F         Albornoz       Hermosilla
# 4             5  228359157      M             Arce         Nahuelpi
# 5             6  23052582K      F           Arenas            Salas
# 6             7  229045555      M           Burgos            Jerez
# 7             8  228317888      M          Cabello          Verdejo
# 8             9  227228512      M          Cabrera          Cabrera
# 9            10  227892277      M          Cabrera           Urbina
# 10           11  227908521      F          Cardona          Montoya
# 11           12  22885803K      F            Cerda         Carrillo
# 12           13  227080205      M         De Pablo           Aliaga
# 13           14  228391484      M             Díaz         Villegas
# 14           15  227110988      M          Faúndez        Herríquez
# 15           16  229071653      F            Gijón          Padilla
# 16           17  228986003      F            Gómez           Zúñiga
# 17           18  22949127K      F           Gormaz          Velasco
# 18           19  229044788      F        Hernández           Castro
# 19           20  22761045K      M           Huerta            Bravo
# 20           21  229412841      F          Humeres            Ulloa
# 21           22  227717173      F             Jaña        Sepulveda
# 22           23  229307142      F            Jones      Valdebenito
# 23           24  227929723      M          Labraña           Maulén
# 24           25  228588113      F          Lacroix          Lacroix
# 25           26  22976134K      M            Lagos             Vera
# 26           27  227098740      F             Lazo          Briones
# 27           28  22590829K      F             Miño            Yañez
# 28           29  224479077      F           Montes          Catalán
# 29           30  228155071      M           Moreno           Parada
# 30           31  229443593      F          Navarro            Navia
# 31           32  227900296      F           Puente       Schnettler
# 32           33  22824192K      F        Ramenzoni           Armijo
# 33           34  225034214      F              Roa           Castro
# 34           35  228010758      M          Rubilar          Catalán
# 35           36  22791419K      M       San Martín         Carrasco
# 36           37  227884770      F        Sepúlveda            Gallo
# 37           38  228032778      F         Trujillo             Jara
# 38           39  228144061      M            Ubeda           Ocares
# 39           40  230350590      F         González             Soto
#
#                     Nombres                                         Email  \
# 0   Krishna Anaís Magdalena     Krishna.acevedo@estudiantes.colegiotgs.cl
# 1         Sebastián Ignacio   Sebastian.acevedo@estudiantes.colegiotgs.cl
# 2          Araksy Francoise      Araksy.aguilar@estudiantes.colegiotgs.cl
# 3             Rocio Ignacia      Rocio.albornoz@estudiantes.colegiotgs.cl
# 4             Emily Shamira          Emily.arce@estudiantes.colegiotgs.cl
# 5             Martín Renato       Martin.arenas@estudiantes.colegiotgs.cl
# 6             Sofía Antonia        Sofia.burgos@estudiantes.colegiotgs.cl
# 7        Sebastián Benjamín   Sebastian.cabello@estudiantes.colegiotgs.cl
# 8             Camilo Javier      Camilo.cabrera@estudiantes.colegiotgs.cl
# 9            Carlos Vicente      Carlos.cabrera@estudiantes.colegiotgs.cl
# 10                  Emanuel     Emanuel.cardona@estudiantes.colegiotgs.cl
# 11          Aylin Constanza         Aylin.cerda@estudiantes.colegiotgs.cl
# 12     María De Los Angeles       Maria.depablo@estudiantes.colegiotgs.cl
# 13         Martín Alejandro         Martin.diaz@estudiantes.colegiotgs.cl
# 14         Javier Alejandro      Javier.faundez@estudiantes.colegiotgs.cl
# 15         Matías Alejandro        Matias.gijon@estudiantes.colegiotgs.cl
# 16         Josefina Antonia      Josefina.gomez@estudiantes.colegiotgs.cl
# 17          Benjamín Felipe     Benjamin.gormaz@estudiantes.colegiotgs.cl
# 18        Paulina Alejandra   Paulina.hernandez@estudiantes.colegiotgs.cl
# 19         Trinidad Antonia     Trinidad.huerta@estudiantes.colegiotgs.cl
# 20        Javiera Alejandra     Javiera.humeres@estudiantes.colegiotgs.cl
# 21          Matilda Ornella        Matilda.jana@estudiantes.colegiotgs.cl
# 22         Florencia Pascal     Florencia.jones@estudiantes.colegiotgs.cl
# 23        Benjamín Fernando    Benjamin.labrana@estudiantes.colegiotgs.cl
# 24           Gaston Alfonso      Gaston.lacroix@estudiantes.colegiotgs.cl
# 25                Florencia     Florencia.lagos@estudiantes.colegiotgs.cl
# 26            Álvaro Adolfo         Alvaro.lazo@estudiantes.colegiotgs.cl
# 27             Mariaignacia   Mariaignacia.mino@estudiantes.colegiotgs.cl
# 28         Agustina Ignacia     Agustina.montes@estudiantes.colegiotgs.cl
# 29      Antonella Alexandra    Antonella.moreno@estudiantes.colegiotgs.cl
# 30            María Ignacia       Maria.navarro@estudiantes.colegiotgs.cl
# 31         Benjamin Ignacio     Benjamin.puente@estudiantes.colegiotgs.cl
# 32             Agustina Paz  Agustina.ramenzoni@estudiantes.colegiotgs.cl
# 33             Jorge Andrés           Jorge.roa@estudiantes.colegiotgs.cl
# 34           Lindsay Andrea     Lindsay.rubilar@estudiantes.colegiotgs.cl
# 35         Sergio Alejandro    Sergio.sanmartin@estudiantes.colegiotgs.cl
# 36           Gustavo Andrés   Gustavo.sepulveda@estudiantes.colegiotgs.cl
# 37            Aranza Simone     Aranza.trujillo@estudiantes.colegiotgs.cl
# 38          Isidora Ignacia       Isidora.ubeda@estudiantes.colegiotgs.cl
# 39         Kristen Almendra    kristen.gonzalez@estudiantes.colegiotgs.cl
#
#     Fono estudiante                           Dirección del estudiante  \
# 0               NaN      Carlos rojas Villalon 580 villa los artesanos
# 1               NaN          Luis Lopez Orellana 2628 villa jorge muoz
# 2               NaN                     Cecilia 299 villa las palmeras
# 3               NaN     Condominio san luis parcela 57 calera de tango
# 4               NaN                            Juanita coria duran 365
# 5               NaN  Calle los pajarito s/n altura 1200 condominio ...
# 6               NaN    Camino el papagayo sector el mirador sin numero
# 7               NaN                 Camino la palma parcela 11 lote 33
# 8               NaN             Av troncal 700 depto 15 las praderas 2
# 9        63387728.0                Las Vertientes, 2 casa 180, Peaflor
# 10              NaN                Villa Cantaros De Agua Pje 6 N 3313
# 11              NaN                                   El olivetto 0160
# 12              NaN                               Av vicua mackena 350
# 13              NaN          Nueva Peaflor pasaje 11 casa 423, Peaflor
# 14              NaN         Cordillera de la sal 197 villa la arboleda
# 15              NaN  Margot dualde soto mayo 010 manzana 20 villa m...
# 16              NaN        Villa cantaros de agua pasaje 5 numero 3282
# 17              NaN                               Francisco hidalgo 57
# 18              NaN  Pje Socio Jonathan Bravo 3662 villa puertas de...
# 19              NaN                 Armijo 206 Casa A Cond. Sta Isabel
# 20              NaN                 Pje cecilia 299 villa las palmeras
# 21              NaN  Camino Interior (loreto) S/n Condominio La Caa...
# 22              NaN             Presvitero feliz saragoza 2163 malloco
# 23              NaN                                     Pje Peumo 2611
# 24              NaN                                  Jose quintero 716
# 25              NaN                              Pasaje Jerusalem 1707
# 26              NaN          Villa cantaros de agua pasaje 7 casa 3300
# 27              NaN    Pasaje lago chungar 1241 B villa santa blanca 3
# 28              NaN                          Las Aguilas 3007, Peaflor
# 29              NaN                   CAmino El Huanaco, 6000 Peaflor.
# 30              NaN       Pasaje los Hilanderos 1383, Valle el Encanto
# 31              NaN                      Parroco agustin lobos sur 608
# 32      931999539.0                                   Moises Chacon 71
# 33              NaN              Granate 572 Villa el cuarso, el Monte
# 34              NaN                      Pje 3 Casa 329 villa la palma
# 35              NaN          Luis lopez orellana 2641 villa jorge muoz
# 36              NaN                                     Villarica 2269
# 37              NaN  Calle San Guillermo Parcela 114 Condominio Don...
# 38              NaN                 Paula Verdugo 322 villa los heroes
# 39      949336228.0                                     los ulmos 2896
#
#    Nombre contacto emergencia  Fono emergencia
# 0                         NaN              NaN
# 1                         NaN              NaN
# 2                         NaN              NaN
# 3                         NaN              NaN
# 4                         NaN              NaN
# 5                         NaN              NaN
# 6                         NaN              NaN
# 7                         NaN              NaN
# 8                         NaN              NaN
# 9                         NaN              NaN
# 10                        NaN              NaN
# 11                        NaN              NaN
# 12                        NaN              NaN
# 13                        NaN              NaN
# 14                        NaN              NaN
# 15                        NaN              NaN
# 16                        NaN              NaN
# 17                        NaN              NaN
# 18                        NaN              NaN
# 19                        NaN              NaN
# 20                        NaN              NaN
# 21                        NaN              NaN
# 22                        NaN              NaN
# 23                        NaN              NaN
# 24                        NaN              NaN
# 25                        NaN              NaN
# 26                        NaN              NaN
# 27                        NaN              NaN
# 28                        NaN              NaN
# 29                        NaN              NaN
# 30                        NaN              NaN
# 31                        NaN              NaN
# 32               Nancy Armijo      931999539.0
# 33                        NaN              NaN
# 34                        NaN              NaN
# 35                        NaN              NaN
# 36                        NaN              NaN
# 37                        NaN              NaN
# 38                        NaN              NaN
# 39                        NaN              NaN

# %%
for run, email in zip(df_users_II_G['RUN'], df_users_II_G['Email']):
    insert_email(run, email)

# %%
read_table('emails')
# Out:
#     id                                             email        run  \
# 0   34          Bastian.armijo@estudiantes.colegiotgs.cl  228756466
# 1   35          bastian.barros@estudiantes.colegiotgs.cl  229306154
# 2   36          Viviana.canete@estudiantes.colegiotgs.cl  228141984
# 3   37           Vicente.celis@estudiantes.colegiotgs.cl  22739630K
# 4   38       Contreras.agustin@estudiantes.colegiotgs.cl  229240994
# 5   39       Franco.delafuente@estudiantes.colegiotgs.cl  228576964
# 6   40  Maximiliano.delapuente@estudiantes.colegiotgs.cl  229798081
# 7   41          Martina.donoso@estudiantes.colegiotgs.cl  227786353
# 8   42         Bastian.escobar@estudiantes.colegiotgs.cl  228311898
# 9   43          Gaspar.fuentes@estudiantes.colegiotgs.cl  228746746
# 10  44           Leila.garrido@estudiantes.colegiotgs.cl  229535528
# 11  45        Claudio.gonzalez@estudiantes.colegiotgs.cl  228757454
# 12  46        Francisca.huerta@estudiantes.colegiotgs.cl  227610700
# 13  47             Samuel.jara@estudiantes.colegiotgs.cl  227310596
# 14  48       Santiago.letelier@estudiantes.colegiotgs.cl  229005952
# 15  49        Vicente.letelier@estudiantes.colegiotgs.cl  229006231
# 16  50        Antonia.liberona@estudiantes.colegiotgs.cl  227655011
# 17  51          Renata.llanten@estudiantes.colegiotgs.cl  230444617
# 18  52          Tomas.marchant@estudiantes.colegiotgs.cl  227412658
# 19  53        Leticia.martinez@estudiantes.colegiotgs.cl  227615591
# 20  54          Josefa.morales@estudiantes.colegiotgs.cl  227716975
# 21  55       Alejandro.morales@estudiantes.colegiotgs.cl  229785656
# 22  56          Matias.morales@estudiantes.colegiotgs.cl  226225609
# 23  57              Karla.moya@estudiantes.colegiotgs.cl  229814648
# 24  58            Emilia.munoz@estudiantes.colegiotgs.cl  229799614
# 25  59         Isidora.navarro@estudiantes.colegiotgs.cl  229996118
# 26  60     Monserratt.nincolaf@estudiantes.colegiotgs.cl  228895539
# 27  61           Matilde.ojeda@estudiantes.colegiotgs.cl  228365831
# 28  62            Maria.olguin@estudiantes.colegiotgs.cl  22765497K
# 29  63            Franco.oliva@estudiantes.colegiotgs.cl  230407029
# 30  64         Martin.olivares@estudiantes.colegiotgs.cl  229607251
# 31  65            Matias.ortiz@estudiantes.colegiotgs.cl  228630845
# 32  66         Florencia.perez@estudiantes.colegiotgs.cl  227954299
# 33  67              Diego.pino@estudiantes.colegiotgs.cl  229180649
# 34  68           Juan.riquelme@estudiantes.colegiotgs.cl  227044810
# 35  69          Romero.antonia@estudiantes.colegiotgs.cl  229149059
# 36  70           Josefa.toledo@estudiantes.colegiotgs.cl  230515492
# 37  71          Matias.venegas@estudiantes.colegiotgs.cl  229135740
# 38  72             Daniel.vera@estudiantes.colegiotgs.cl  229338951
# 39  73          Martin.vilches@estudiantes.colegiotgs.cl  229952331
# 40  74              paz.guzman@estudiantes.colegiotgs.cl  228908061
#
#              created_at
# 0   2024-09-11 19:19:10
# 1   2024-09-11 19:19:10
# 2   2024-09-11 19:19:10
# 3   2024-09-11 19:19:10
# 4   2024-09-11 19:19:10
# 5   2024-09-11 19:19:10
# 6   2024-09-11 19:19:10
# 7   2024-09-11 19:19:10
# 8   2024-09-11 19:19:10
# 9   2024-09-11 19:19:10
# 10  2024-09-11 19:19:10
# 11  2024-09-11 19:19:10
# 12  2024-09-11 19:19:10
# 13  2024-09-11 19:19:10
# 14  2024-09-11 19:19:10
# 15  2024-09-11 19:19:10
# 16  2024-09-11 19:19:10
# 17  2024-09-11 19:19:10
# 18  2024-09-11 19:19:10
# 19  2024-09-11 19:19:10
# 20  2024-09-11 19:19:10
# 21  2024-09-11 19:19:10
# 22  2024-09-11 19:19:10
# 23  2024-09-11 19:19:10
# 24  2024-09-11 19:19:10
# 25  2024-09-11 19:19:10
# 26  2024-09-11 19:19:10
# 27  2024-09-11 19:19:10
# 28  2024-09-11 19:19:10
# 29  2024-09-11 19:19:10
# 30  2024-09-11 19:19:10
# 31  2024-09-11 19:19:10
# 32  2024-09-11 19:19:10
# 33  2024-09-11 19:19:10
# 34  2024-09-11 19:19:10
# 35  2024-09-11 19:19:10
# 36  2024-09-11 19:19:10
# 37  2024-09-11 19:19:10
# 38  2024-09-11 19:19:10
# 39  2024-09-11 19:19:10
# 40  2024-09-11 19:19:10

# %% [markdown]
# ## Verificar si el email ya existe en la base de datos

# %%
def verify_email(email):
    conn = sqlite3.connect("form_app.db")
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM emails WHERE email = ?", (email,))
    result = cursor.fetchone()
    if result:
        conn.close()
        return True

    else:
        conn.close()
        return False

# %% [markdown]
# ## Insertar un registro de una inscripción de electivos en la base de datos

# %%
def insert_user_record(name, run, email, curso, electivo_1, electivo_2, electivo_3, electivo_fg):
    conn = sqlite3.connect("form_app.db")
    cursor = conn.cursor()

    try:
        cursor.execute(
            "INSERT INTO users_register (name, run, email, curso, electivo_1, electivo_2, electivo_3, electivo_fg) VALUES (?, ?, ?, ?, ?, ?, ?, ?)",
            (name, run, email, curso, electivo_1, electivo_2, electivo_3, electivo_fg),
        )
        conn.commit()  # Guarda los cambios
        print("Registro insertado correctamente.")
        return True  # Devuelve True si la inserción fue exitosa
    except Exception as e:
        print(f"Error al insertar el registro: {e}")
        return False  # Devuelve False si hubo un error
    finally:
        conn.close()  # Asegúrate de cerrar la conexión

# %%
def verify_email(email):
    conn = sqlite3.connect("form_app.db")
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM emails WHERE email = ?", (email,))
    result = cursor.fetchone()
    if result:
        conn.close()
        return True

    else:
        conn.close()
        return False

# %%
def insert_electives(nombre_electivo):
    conn = sqlite3.connect("form_app.db")
    cursor = conn.cursor()
    cursor.execute(
        "INSERT INTO electives_control (electivos_disponibles) VALUES (?)",
        (nombre_electivo,),
    )
    conn.commit()
    conn.close()
    return True

# %%
def drop_columns(table_name, columns):
    conn = sqlite3.connect("form_app.db")
    cursor = conn.cursor()
    for column in columns:
        cursor.execute(f"ALTER TABLE {table_name} DROP COLUMN {column}")
    conn.commit()
    conn.close()
    return True

# %%
import pandas as pd
path = "Control_Electivos.csv"

df_electivos = pd.read_csv(path)
df_electivos.head(20)
# Out:
#                                 Electivos Disponibles  Cantidad de Inscritos  \
# 0          Área A: Comprensión Histórica del Presente                      0
# 1             Área B: Límites, Derivadas e Integrales                      0
# 2                      Área C: Interpretación Musical                      0
# 3                        Área A: Taller de literatura                      0
# 4               Área B: Biología celular y molecular.                      0
# 5   Área B: Pensamiento computacional y programación.                      0
# 6   Área C: Artes visuales, audiovisuales y multim...                      0
# 7           Área A: Lectura y escritura especializada                      0
# 8                                     Área B: Química                      0
# 9   Área C: Ciencias del ejercicio físico y deportivo                      0
# 10                 Historia, Geografía y Cs. Sociales                      0
# 11                                      Arte Visuales                      0
#
#     Cupo Disponible  Cupo Asignado
# 0                25             25
# 1                25             25
# 2                25             25
# 3                25             25
# 4                25             25
# 5                25             25
# 6                25             25
# 7                25             25
# 8                25             25
# 9                25             25
# 10               25             25
# 11               25             25

# %%
for elective in df_electivos["Electivos Disponibles"]:
    insert_electives(elective)

# %%
read_table("electives_control", "form_app.db")
# Out:
#     id                              electivos_disponibles
# 0    1         Área A: Comprensión Histórica del Presente
# 1    2            Área B: Límites, Derivadas e Integrales
# 2    3                     Área C: Interpretación Musical
# 3    4                       Área A: Taller de literatura
# 4    5              Área B: Biología celular y molecular.
# 5    6  Área B: Pensamiento computacional y programación.
# 6    7  Área C: Artes visuales, audiovisuales y multim...
# 7    8          Área A: Lectura y escritura especializada
# 8    9                                    Área B: Química
# 9   10  Área C: Ciencias del ejercicio físico y deportivo
# 10  11                 Historia, Geografía y Cs. Sociales
# 11  12                                      Arte Visuales
# 12  13         Área A: Comprensión Histórica del Presente
# 13  14            Área B: Límites, Derivadas e Integrales
# 14  15                     Área C: Interpretación Musical
# 15  16                       Área A: Taller de literatura
# 16  17              Área B: Biología celular y molecular.
# 17  18  Área B: Pensamiento computacional y programación.
# 18  19  Área C: Artes visuales, audiovisuales y multim...
# 19  20          Área A: Lectura y escritura especializada
# 20  21                                    Área B: Química
# 21  22  Área C: Ciencias del ejercicio físico y deportivo
# 22  23                 Historia, Geografía y Cs. Sociales
# 23  24                                      Arte Visuales

# %% [markdown]
# ## Contar la cantidad de inscripciones por electivo

# %%
def validate_elective_availability(
    electivo_elegido: str, electivo: str, availavity: int
):
    conn = sqlite3.connect("form_app.db")
    cursor = conn.cursor()

    try:
        cursor.execute(
            f"SELECT COUNT({electivo}) FROM users_register WHERE {electivo} = ?",
            (electivo_elegido,),
        )
        result = cursor.fetchone()
        if result[0] >= availavity:
            return False
        else:
            return result[0], True
    except Exception as e:
        raise e
    finally:
        conn.close()

# %%
validate_elective_availability("Área B: Pensamiento computacional y programación", "electivo_2", 5)
# Out:
# False

# %%
def validate_elective_availability_fg(electivo_fg: str, curso: str, availavity: int, ):
    conn = sqlite3.connect("form_app.db")
    cursor = conn.cursor()

    try:
        cursor.execute(
            f"SELECT COUNT(electivo_fg) FROM users_register WHERE electivo_fg = ? AND curso = ?",
            (electivo_fg, curso),
        )
        result = cursor.fetchone()
        if result[0] >= availavity:
            return True
        else:
            return False
    except Exception as e:
        raise e
    finally:
        conn.close()

# %%
validate_elective_availability_fg("Historia, Geografía y Cs. Sociales", "III BLUE", 10)
# Out:
# 0

# %%
def validate_run_email(run: str, email: str, table_name="users_register"):
    conn = sqlite3.connect("form_app.db")
    cursor = conn.cursor()

    try:
        cursor.execute(
            f"SELECT run, email FROM {table_name} WHERE run = ? AND email = ?",
            (run, email),
        )
        result = cursor.fetchone()
        return True if result else False

    except Exception as e:
        raise e
    finally:
        conn.close()

# %%
validate_run_email('12256365-8', 'ilaqueso17@gmail.com', 'emails')
# Out:
# False

# %%
def insert_data_electivos_2024_3_medio(run, curso, electivo_1, electivo_2, electivo_3):
    conn = sqlite3.connect('form_app.db')
    cursor = conn.cursor()
    cursor.execute(
        """
        INSERT INTO listado_electivos_2024_3_medio (run, curso, electivo_1, electivo_2, electivo_3)
        VALUES (?, ?, ?, ?, ?)
        """,
        (run, curso, electivo_1, electivo_2, electivo_3),
    )
    conn.commit()
    conn.close()

# %%
df_electivos_2024_3_medio = pd.read_csv("./listado_electivos_2024_3_medio.csv")

# %%
cols = list(df_electivos_2024_3_medio.columns)

# %%
for index, row in df_electivos_2024_3_medio.iterrows():
    r = row[cols[0]]
    c = row[cols[1]]
    e1 = row[cols[2]]
    e2 = row[cols[3]]
    e3 = row[cols[4]]
    insert_data_electivos_2024_3_medio(r, c, e1, e2, e3)

# %%
def verify_electivo_prior_year(run: str, electivo: str):

    run = run.replace("-", "")

    conn = sqlite3.connect("form_app.db")
    cursor = conn.cursor()

    try:
        cursor.execute(
            f"SELECT run, electivo_1, electivo_2, electivo_3 FROM listado_electivos_2024_3_medio WHERE run = ?",
            (run,),
        )
        result = cursor.fetchone()
        if result:
            if electivo in list(result[1:]):
                return True
            else:
                return False
    except Exception as e:
        raise e
    finally:
        conn.close()

# %%
verify_electivo_prior_year("22464776-K", "Economía y Sociedad")
# Out:
# True

# %%
'Interpretación Musical'

# %%
table_name = "listado_electivos_2024_3_medio"
db = "form_app.db"

read_table(table_name, db)
# Out:
#     id        run       curso                     electivo_1  \
# 0    1  224332564  3º Medio B                         Física
# 1    2  22464776K  3º Medio A  Participación y Argumentación
# 2    3  224793626  3º Medio B          Diseño y arquitectura
# 3    4  224793839  3º Medio B  Participación y Argumentación
# 4    5  225014434  3º Medio A  Participación y Argumentación
# ..  ..        ...         ...                            ...
# 69  70  226483306  3º Medio B  Participación y Argumentación
# 70  71  226600493  3º Medio A  Participación y Argumentación
# 71  72  226821848  3º Medio B          Diseño y arquitectura
# 72  73  227016558  3º Medio B  Participación y Argumentación
# 73  74  227150645  3º Medio B                         Física
#
#                                    electivo_2              electivo_3
# 0   Ciencias del Ejercicio Físico y Deportivo  Interpretación Musical
# 1                         Economía y Sociedad  Interpretación Musical
# 2                Biología celular y molecular  Interpretación Musical
# 3                         Economía y Sociedad  Interpretación Musical
# 4                         Economía y Sociedad  Interpretación Musical
# ..                                        ...                     ...
# 69                       Ciencias de la salud  Seminario de filosofía
# 70                       Ciencias de la salud  Seminario de filosofía
# 71               Biología celular y molecular  Seminario de filosofía
# 72                       Ciencias de la salud  Seminario de filosofía
# 73  Ciencias del Ejercicio Físico y Deportivo  Seminario de filosofía
#
# [74 rows x 6 columns]
